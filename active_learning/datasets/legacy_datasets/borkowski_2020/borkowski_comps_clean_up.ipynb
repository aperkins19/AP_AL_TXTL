# %%
import pandas as pd

# %%
df = pd.read_csv("borkowski_comps_1017.csv", header = None).T
df = df.iloc[:1018,:]
df.columns = df.iloc[0,:]
df = df.iloc[1:,:]
df
# Out:
# 0    Mg-glutamate (mM) K-glutamate (mM) Amino Acid (mM) tRNA (mg/ml) coA (mM)  \
# 1                  4.0             80.0             1.5          0.2     0.26
# 2                  0.4             80.0             1.5          0.2     0.26
# 3                  4.0             80.0             1.5          0.2     0.26
# 4                  1.2             40.0            0.45         0.02    0.078
# 5                  4.0             80.0             1.5          0.2     0.26
# ...                ...              ...             ...          ...      ...
# 1013               4.0             80.0             1.5         0.06    0.078
# 1014               4.0             80.0             1.5          0.1    0.026
# 1015               4.0             80.0             1.5         0.06    0.078
# 1016               4.0             80.0             1.5          0.1    0.026
# 1017               4.0             80.0             1.5         0.06    0.026
#
# ...

# %%
df.to_csv("borkowski_comps_1017_prepped.csv", index= False)
